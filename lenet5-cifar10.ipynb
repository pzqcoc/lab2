# %%
import argparse
import os, sys
import time
import datetime
import matplotlib.pyplot as plt

# Import pytorch dependencies
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import torch.optim as optim
from tqdm import tqdm_notebook as tqdm

# You cannot change this line.
from tools.dataloader import CIFAR10

# %%
""" 
Assignment 2(a)
Build the LeNet-5 model by following table 1 or figure 1.

You can also insert batch normalization and leave the LeNet-5 
with batch normalization here for assignment 3(c).
"""
# Create the neural network module: LeNet-5
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 6, 5)
        self.conv1_bn = nn.BatchNorm2d(6)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.conv2_bn = nn.BatchNorm2d(16)
        self.fc1 = nn.Linear(16*5*5, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)
        
    def forward(self, x):
        out = self.conv1(x)
        out = self.conv1_bn(out)
        out = F.relu(out)
        out = F.max_pool2d(out, 2)
        out = self.conv2(out)
        out = self.conv2_bn(out)
        out = F.relu(out)
        out = F.max_pool2d(out, 2)
        out = out.view(out.size(0), -1)
        out = F.relu(self.fc1(out))
        out = F.relu(self.fc2(out))
        out = self.fc3(out)
        return out

# %%
"""
Hyperparameter optimization in assignment 4(a), 4(b) can be 
conducted here.
Be sure to leave only your best hyperparameter combination
here and comment the original hyperparameter settings.
"""

# Setting some hyperparameters
TRAIN_BATCH_SIZE = 128
VAL_BATCH_SIZE = 100
INITIAL_LR = 0.08
# INITIAL_LR = 0.01
MOMENTUM = 0.9
REG = 1e-4
EPOCHS = 50
# EPOCHS = 30
DECAY_EPOCHS = 2
DECAY = 0.9 
DATAROOT = "./data"
CHECKPOINT_PATH = "./saved_model"

# %% [markdown]
# **Your answer:**

# %%
"""
Assignment 2(b)
Write functions to load dataset and preprocess the incoming data. 
We recommend that the preprocess scheme \textbf{must} include 
normalize, standardization, batch shuffling to make sure the training 
process goes smoothly. 
The preprocess scheme may also contain some data augmentation methods 
(e.g., random crop, random flip, etc.). 

Reference value for mean/std:

mean(RGB-format): (0.4914, 0.4822, 0.4465)
std(RGB-format): (0.2023, 0.1994, 0.2010)


NOTE: Considering this process has strong corrlelation with assignment 3(b), 
please leave the data preprocessing method which can achieve the highest 
validation accuracy here. You can include your original data augmentation
method as comments and denotes the accuracy difference between thest two 
methods.
"""
# Specify preprocessing function.
# Reference mean/std value for 
transform_train = transforms.Compose([transforms.RandomHorizontalFlip(),transforms.RandomCrop(32, padding=4),transforms.ToTensor(),transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),])
# transform_train = transforms.Compose([transforms.ToTensor(),transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),])
transform_val = transforms.Compose([transforms.ToTensor(),transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),])

# %% [markdown]
# **Your answer:**

# %%
# Call the dataset Loader
trainset = CIFAR10(root=DATAROOT, train=True, download=True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=TRAIN_BATCH_SIZE, shuffle=True, num_workers=1)
valset = CIFAR10(root=DATAROOT, train=False, download=True, transform=transform_val)
valloader = torch.utils.data.DataLoader(valset, batch_size=VAL_BATCH_SIZE, shuffle=False, num_workers=1)
# Out:
# Using downloaded and verified file: ./data/cifar10_trainval.tar.gz
# Extracting ./data/cifar10_trainval.tar.gz to ./data
# Files already downloaded and verified
# Using downloaded and verified file: ./data/cifar10_trainval.tar.gz
# Extracting ./data/cifar10_trainval.tar.gz to ./data
# Files already downloaded and verified

# %%
# Specify the device for computation
device = 'cuda' if torch.cuda.is_available() else 'cpu'
net = LeNet5()
net = net.to(device)
if device =='cuda':
    print("Train on GPU...")
else:
    print("Train on CPU...")
# Out:
# Train on GPU...

# %%
# FLAG for loading the pretrained model
TRAIN_FROM_SCRATCH = False
# Code for loading checkpoint and recover epoch id.
CKPT_PATH = "./saved_model/model.h5"
def get_checkpoint(ckpt_path):
    try:
        ckpt = torch.load(ckpt_path)
    except Exception as e:
        print(e)
        return None
    return ckpt

ckpt = get_checkpoint(CKPT_PATH)
if ckpt is None or TRAIN_FROM_SCRATCH:
    if not TRAIN_FROM_SCRATCH:
        print("Checkpoint not found.")
    print("Training from scratch ...")
    start_epoch = 0
    current_learning_rate = INITIAL_LR
else:
    print("Successfully loaded checkpoint: %s" %CKPT_PATH)
    net.load_state_dict(ckpt['net'])
    start_epoch = ckpt['epoch'] + 1
    current_learning_rate = ckpt['lr']
    print("Starting from epoch %d " %start_epoch)

print("Starting from learning rate %f:" %current_learning_rate)
# Out:
# [Errno 2] No such file or directory: './saved_model/model.h5'
# Checkpoint not found.
# Training from scratch ...
# Starting from learning rate 0.080000:

# %%
"""
Assignment 2(c)
In the targeted classification task, we use cross entropy loss with L2 
regularization as the learning object.
You need to formulate the cross-entropy loss function in PyTorch.
You should also specify a PyTorch Optimizer to optimize this loss function.
We recommend you to use the SGD-momentum with an initial learning rate 0.01 
and momentum 0.9 as a start.
"""
# Create loss function and specify regularization
criterion = nn.CrossEntropyLoss()
# Add optimizer
optimizer = optim.SGD(net.parameters(), lr=INITIAL_LR, momentum=MOMENTUM, weight_decay=REG)

# %%
"""
Assignment 3(a)
Start the training process over the whole CIFAR-10 training dataset. 
For sanity check, you are required to report the initial loss value at 
the beginning of the training process and briefly justify this value. 
Run the training process for \textbf{a maximum of 30} epochs and you 
should be able to reach around \textbf{65\%} accuracy on the validation 
dataset.
"""
# Start the training/validation process
# The process should take about 5 minutes on a GTX 1070-Ti
# if the code is written efficiently.
global_step = 0
best_val_acc = 0

training_losses = []
training_accuracies = []
validation_losses = []
validation_accuracies = []
epoches = []

for i in range(start_epoch, EPOCHS):
    epoches.append(i)
    print(datetime.datetime.now())
    # Switch to train mode
    net.train()
    print("Epoch %d:" %i)

    total_examples = 0
    correct_examples = 0

    train_loss = 0
    train_acc = 0
    # Train the training dataset for 1 epoch.
    print(len(trainloader))
    for batch_idx, (inputs, targets) in enumerate(trainloader):
        # Copy inputs to device
        inputs = inputs.to(device)
        targets = targets.to(device)
        # Zero the gradient
        optimizer.zero_grad()
        # Generate output
        outputs = net(inputs)
        loss = criterion(outputs, targets)
        # Now backward loss
        loss.backward()
        # Apply gradient
        # print("initial loss training loss %.4f" %loss)
        optimizer.step()
        # Calculate predicted labels
        _, predicted = outputs.max(1)
        # Calculate accuracy
        total_examples += len(inputs)
        correct_examples += (predicted==targets).sum().item()

        train_loss += loss

        global_step += 1
        if global_step % 100 == 0:
            avg_loss = train_loss / (batch_idx + 1)
        pass
    avg_acc = correct_examples / total_examples
    print("Training loss: %.4f, Training accuracy: %.4f" %(avg_loss, avg_acc))
    training_losses.append(avg_loss)
    training_accuracies.append(avg_acc)
    print(datetime.datetime.now())
    # Validate on the validation dataset
    print("Validation...")
    total_examples = 0
    correct_examples = 0
    
    net.eval()

    val_loss = 0
    val_acc = 0
    # Disable gradient during validation
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(valloader):
            # Copy inputs to device
            inputs = inputs.to(device)
            targets = targets.to(device)
            # Zero the gradient
            optimizer.zero_grad()
            # Generate output from the DNN.
            outputs = net(inputs)
            loss = criterion(outputs, targets)
            # Calculate predicted labels
            _, predicted = outputs.max(1)
            # Calculate accuracy
            total_examples += len(inputs)
            correct_examples += (predicted==targets).sum().item()
            val_loss += loss

    avg_loss = val_loss / len(valloader)
    avg_acc = correct_examples / total_examples
    print("Validation loss: %.4f, Validation accuracy: %.4f" % (avg_loss, avg_acc))
    validation_losses.append(avg_loss)
    validation_accuracies.append(avg_acc)
        
    """
    Assignment 4(b)
    Learning rate is an important hyperparameter to tune. Specify a 
    learning rate decay policy and apply it in your training process. 
    Briefly describe its impact on the learning curveduring your 
    training process.    
    Reference learning rate schedule: 
    decay 0.98 for every 2 epochs. You may tune this parameter but 
    minimal gain will be achieved.
    Assignment 4(c)
    As we can see from above, hyperparameter optimization is critical 
    to obtain a good performance of DNN models. Try to fine-tune the 
    model to over 70% accuracy. You may also increase the number of 
    epochs to up to 100 during the process. Briefly describe what you 
    have tried to improve the performance of the LeNet-5 model.
    """
      
    if i % DECAY_EPOCHS == 0 and i != 0:
        current_learning_rate = current_learning_rate * DECAY
        for param_group in optimizer.param_groups:
            # Assign the learning rate parameter
            param_group['lr'] = current_learning_rate
        print("Current learning rate has decayed to %f" %current_learning_rate)
    
    # Save for checkpoint
    if avg_acc > best_val_acc:
        best_val_acc = avg_acc
        if not os.path.exists(CHECKPOINT_PATH):
            os.makedirs(CHECKPOINT_PATH)
        print("Saving ...")
        state = {'net': net.state_dict(),
                 'epoch': i,
                 'lr': current_learning_rate}
        torch.save(state, os.path.join(CHECKPOINT_PATH, 'model.h5'))

print("Optimization finished.")
# Out:
# 2019-09-29 22:50:30.955912
# Epoch 0:
# 352
# Training loss: 1.7314, Training accuracy: 0.3635
# 2019-09-29 22:50:43.188899
# Validation...
# Validation loss: 1.4873, Validation accuracy: 0.4420
# Saving ...
# 2019-09-29 22:50:44.326094
# Epoch 1:
# 352
# Training loss: 1.4851, Training accuracy: 0.4561
# 2019-09-29 22:50:56.116738
# Validation...
# Validation loss: 1.3294, Validation accuracy: 0.5220
# Saving ...
# 2019-09-29 22:50:57.455448
# Epoch 2:
# 352
# Training loss: 1.3932, Training accuracy: 0.4989
# 2019-09-29 22:51:09.862564
# Validation...
# Validation loss: 1.3159, Validation accuracy: 0.5334
# Current learning rate has decayed to 0.072000
# Saving ...
# 2019-09-29 22:51:11.091256
# Epoch 3:
# 352
# Training loss: 1.3217, Training accuracy: 0.5267
# 2019-09-29 22:51:23.654206
# Validation...
# Validation loss: 1.2108, Validation accuracy: 0.5666
# Saving ...
# 2019-09-29 22:51:24.909966
# Epoch 4:
# 352
# Training loss: 1.2915, Training accuracy: 0.5410
# 2019-09-29 22:51:36.901765
# Validation...
# Validation loss: 1.1841, Validation accuracy: 0.5752
# Current learning rate has decayed to 0.064800
# Saving ...
# 2019-09-29 22:51:38.196863
# Epoch 5:
# 352
# Training loss: 1.2334, Training accuracy: 0.5591
# 2019-09-29 22:51:51.099558
# Validation...
# Validation loss: 1.1127, Validation accuracy: 0.6022
# Saving ...
# 2019-09-29 22:51:52.275259
# Epoch 6:
# 352
# Training loss: 1.2059, Training accuracy: 0.5722
# 2019-09-29 22:52:04.335946
# Validation...
# Validation loss: 1.1501, Validation accuracy: 0.5938
# Current learning rate has decayed to 0.058320
# 2019-09-29 22:52:05.452105
# Epoch 7:
# 352
# Training loss: 1.1658, Training accuracy: 0.5848
# 2019-09-29 22:52:17.753091
# Validation...
# Validation loss: 1.1081, Validation accuracy: 0.6112
# Saving ...
# 2019-09-29 22:52:18.929767
# Epoch 8:
# 352
# Training loss: 1.1528, Training accuracy: 0.5899
# 2019-09-29 22:52:31.848734
# Validation...
# Validation loss: 1.0880, Validation accuracy: 0.6124
# Current learning rate has decayed to 0.052488
# Saving ...
# 2019-09-29 22:52:33.117061
# Epoch 9:
# 352
# Training loss: 1.1153, Training accuracy: 0.6037
# 2019-09-29 22:52:45.148468
# Validation...
# Validation loss: 1.0232, Validation accuracy: 0.6348
# Saving ...
# 2019-09-29 22:52:46.355387
# Epoch 10:
# 352
# Training loss: 1.1035, Training accuracy: 0.6083
# 2019-09-29 22:52:58.870709
# Validation...
# Validation loss: 1.0584, Validation accuracy: 0.6282
# Current learning rate has decayed to 0.047239
# 2019-09-29 22:53:00.089830
# Epoch 11:
# 352
# Training loss: 1.0848, Training accuracy: 0.6146
# 2019-09-29 22:53:12.296778
# Validation...
# Validation loss: 1.0525, Validation accuracy: 0.6312
# 2019-09-29 22:53:13.461553
# Epoch 12:
# 352
# Training loss: 1.0684, Training accuracy: 0.6200
# 2019-09-29 22:53:26.198563
# Validation...
# Validation loss: 0.9952, Validation accuracy: 0.6540
# Current learning rate has decayed to 0.042515
# Saving ...
# 2019-09-29 22:53:27.385217
# Epoch 13:
# 352
# Training loss: 1.0460, Training accuracy: 0.6310
# 2019-09-29 22:53:40.062040
# Validation...
# Validation loss: 0.9887, Validation accuracy: 0.6460
# 2019-09-29 22:53:41.254571
# Epoch 14:
# 352
# Training loss: 1.0349, Training accuracy: 0.6322
# 2019-09-29 22:53:53.881831
# Validation...
# Validation loss: 0.9590, Validation accuracy: 0.6578
# Current learning rate has decayed to 0.038264
# Saving ...
# 2019-09-29 22:53:55.087558
# Epoch 15:
# 352
# Training loss: 1.0129, Training accuracy: 0.6410
# 2019-09-29 22:54:07.010554
# Validation...
# Validation loss: 0.9613, Validation accuracy: 0.6598
# Saving ...
# 2019-09-29 22:54:08.261657
# Epoch 16:
# 352
# Training loss: 1.0133, Training accuracy: 0.6418
# 2019-09-29 22:54:20.873537
# Validation...
# Validation loss: 0.9344, Validation accuracy: 0.6736
# Current learning rate has decayed to 0.034437
# Saving ...
# 2019-09-29 22:54:22.135283
# Epoch 17:
# 352
# Training loss: 1.0002, Training accuracy: 0.6460
# 2019-09-29 22:54:34.611468
# Validation...
# Validation loss: 0.9458, Validation accuracy: 0.6568
# 2019-09-29 22:54:35.983327
# Epoch 18:
# 352
# Training loss: 0.9926, Training accuracy: 0.6521
# 2019-09-29 22:54:48.349823
# Validation...
# Validation loss: 0.9258, Validation accuracy: 0.6746
# Current learning rate has decayed to 0.030994
# Saving ...
# 2019-09-29 22:54:49.619314
# Epoch 19:
# 352
# Training loss: 0.9678, Training accuracy: 0.6574
# 2019-09-29 22:55:02.306541
# Validation...
# Validation loss: 0.9074, Validation accuracy: 0.6730
# 2019-09-29 22:55:03.478568
# Epoch 20:
# 352
# Training loss: 0.9743, Training accuracy: 0.6572
# 2019-09-29 22:55:15.502128
# Validation...
# Validation loss: 0.9022, Validation accuracy: 0.6862
# Current learning rate has decayed to 0.027894
# Saving ...
# 2019-09-29 22:55:16.964071
# Epoch 21:
# 352
# Training loss: 0.9577, Training accuracy: 0.6608
# 2019-09-29 22:55:29.082896
# Validation...
# Validation loss: 0.8980, Validation accuracy: 0.6784
# 2019-09-29 22:55:30.326548
# Epoch 22:
# 352
# Training loss: 0.9403, Training accuracy: 0.6695
# 2019-09-29 22:55:43.325681
# Validation...
# Validation loss: 0.9327, Validation accuracy: 0.6706
# Current learning rate has decayed to 0.025105
# 2019-09-29 22:55:44.570462
# Epoch 23:
# 352
# Training loss: 0.9403, Training accuracy: 0.6680
# 2019-09-29 22:55:57.744629
# Validation...
# Validation loss: 0.8869, Validation accuracy: 0.6828
# 2019-09-29 22:55:58.964623
# Epoch 24:
# 352
# Training loss: 0.9359, Training accuracy: 0.6700
# 2019-09-29 22:56:11.406557
# Validation...
# Validation loss: 0.8719, Validation accuracy: 0.6878
# Current learning rate has decayed to 0.022594
# Saving ...
# 2019-09-29 22:56:12.664836
# Epoch 25:
# 352
# Training loss: 0.9174, Training accuracy: 0.6768
# 2019-09-29 22:56:24.650906
# Validation...
# Validation loss: 0.9071, Validation accuracy: 0.6840
# 2019-09-29 22:56:25.862542
# Epoch 26:
# 352
# Training loss: 0.9156, Training accuracy: 0.6750
# 2019-09-29 22:56:37.966559
# Validation...
# Validation loss: 0.8730, Validation accuracy: 0.6906
# Current learning rate has decayed to 0.020335
# Saving ...
# 2019-09-29 22:56:39.227282
# Epoch 27:
# 352
# Training loss: 0.9087, Training accuracy: 0.6792
# 2019-09-29 22:56:51.191196
# Validation...
# Validation loss: 0.8766, Validation accuracy: 0.6962
# Saving ...
# 2019-09-29 22:56:52.460723
# Epoch 28:
# 352
# Training loss: 0.8993, Training accuracy: 0.6822
# 2019-09-29 22:57:04.354541
# Validation...
# Validation loss: 0.8403, Validation accuracy: 0.7048
# Current learning rate has decayed to 0.018301
# Saving ...
# 2019-09-29 22:57:05.593155
# Epoch 29:
# 352
# Training loss: 0.8920, Training accuracy: 0.6850
# 2019-09-29 22:57:17.667282
# Validation...
# Validation loss: 0.8517, Validation accuracy: 0.7020
# 2019-09-29 22:57:18.837953
# Epoch 30:
# 352
# Training loss: 0.8822, Training accuracy: 0.6889
# 2019-09-29 22:57:31.565729
# Validation...
# Validation loss: 0.8745, Validation accuracy: 0.6898
# Current learning rate has decayed to 0.016471
# 2019-09-29 22:57:32.791619
# Epoch 31:
# 352
# Training loss: 0.8777, Training accuracy: 0.6901
# 2019-09-29 22:57:44.934979
# Validation...
# Validation loss: 0.8344, Validation accuracy: 0.7048
# 2019-09-29 22:57:46.118935
# Epoch 32:
# 352
# Training loss: 0.8710, Training accuracy: 0.6946
# 2019-09-29 22:57:58.450945
# Validation...
# Validation loss: 0.8352, Validation accuracy: 0.7086
# Current learning rate has decayed to 0.014824
# Saving ...
# 2019-09-29 22:57:59.714644
# Epoch 33:
# 352
# Training loss: 0.8604, Training accuracy: 0.6967
# 2019-09-29 22:58:11.785817
# Validation...
# Validation loss: 0.8318, Validation accuracy: 0.7068
# 2019-09-29 22:58:12.947668
# Epoch 34:
# 352
# Training loss: 0.8705, Training accuracy: 0.6933
# 2019-09-29 22:58:25.231932
# Validation...
# Validation loss: 0.8303, Validation accuracy: 0.7090
# Current learning rate has decayed to 0.013342
# Saving ...
# 2019-09-29 22:58:26.462275
# Epoch 35:
# 352
# Training loss: 0.8546, Training accuracy: 0.6980
# 2019-09-29 22:58:38.230738
# Validation...
# Validation loss: 0.8600, Validation accuracy: 0.6974
# 2019-09-29 22:58:39.399614
# Epoch 36:
# 352
# Training loss: 0.8490, Training accuracy: 0.7005
# 2019-09-29 22:58:51.620122
# Validation...
# Validation loss: 0.8242, Validation accuracy: 0.7108
# Current learning rate has decayed to 0.012008
# Saving ...
# 2019-09-29 22:58:52.808670
# Epoch 37:
# 352
# Training loss: 0.8448, Training accuracy: 0.7018
# 2019-09-29 22:59:05.193136
# Validation...
# Validation loss: 0.8379, Validation accuracy: 0.7030
# 2019-09-29 22:59:06.420171
# Epoch 38:
# 352
# Training loss: 0.8407, Training accuracy: 0.7042
# 2019-09-29 22:59:18.190933
# Validation...
# Validation loss: 0.8111, Validation accuracy: 0.7132
# Current learning rate has decayed to 0.010807
# Saving ...
# 2019-09-29 22:59:19.368719
# Epoch 39:
# 352
# Training loss: 0.8293, Training accuracy: 0.7062
# 2019-09-29 22:59:31.123001
# Validation...
# Validation loss: 0.8094, Validation accuracy: 0.7204
# Saving ...
# 2019-09-29 22:59:32.316157
# Epoch 40:
# 352
# Training loss: 0.8409, Training accuracy: 0.7037
# 2019-09-29 22:59:44.625100
# Validation...
# Validation loss: 0.8315, Validation accuracy: 0.7064
# Current learning rate has decayed to 0.009726
# 2019-09-29 22:59:45.809022
# Epoch 41:
# 352
# Training loss: 0.8309, Training accuracy: 0.7071
# 2019-09-29 22:59:58.160513
# Validation...
# Validation loss: 0.7932, Validation accuracy: 0.7182
# 2019-09-29 22:59:59.341817
# Epoch 42:
# 352
# Training loss: 0.8295, Training accuracy: 0.7081
# 2019-09-29 23:00:11.412115
# Validation...
# Validation loss: 0.8018, Validation accuracy: 0.7200
# Current learning rate has decayed to 0.008754
# 2019-09-29 23:00:12.609158
# Epoch 43:
# 352
# Training loss: 0.8163, Training accuracy: 0.7130
# 2019-09-29 23:00:24.479348
# Validation...
# Validation loss: 0.7901, Validation accuracy: 0.7218
# Saving ...
# 2019-09-29 23:00:25.706195
# Epoch 44:
# 352
# Training loss: 0.8208, Training accuracy: 0.7112
# 2019-09-29 23:00:38.175332
# Validation...
# Validation loss: 0.7890, Validation accuracy: 0.7206
# Current learning rate has decayed to 0.007878
# 2019-09-29 23:00:39.415554
# Epoch 45:
# 352
# Training loss: 0.8102, Training accuracy: 0.7136
# 2019-09-29 23:00:51.583778
# Validation...
# Validation loss: 0.7942, Validation accuracy: 0.7218
# 2019-09-29 23:00:52.780486
# Epoch 46:
# 352
# Training loss: 0.8109, Training accuracy: 0.7123
# 2019-09-29 23:01:04.889576
# Validation...
# Validation loss: 0.8031, Validation accuracy: 0.7132
# Current learning rate has decayed to 0.007090
# 2019-09-29 23:01:06.073948
# Epoch 47:
# 352
# Training loss: 0.7999, Training accuracy: 0.7150
# 2019-09-29 23:01:17.904914
# Validation...
# Validation loss: 0.7935, Validation accuracy: 0.7208
# 2019-09-29 23:01:19.082723
# Epoch 48:
# 352
# Training loss: 0.8046, Training accuracy: 0.7148
# 2019-09-29 23:01:31.023304
# Validation...
# Validation loss: 0.7920, Validation accuracy: 0.7178
# Current learning rate has decayed to 0.006381
# 2019-09-29 23:01:32.252116
# Epoch 49:
# 352
# Training loss: 0.7988, Training accuracy: 0.7150
# 2019-09-29 23:01:44.487591
# Validation...
# Validation loss: 0.7776, Validation accuracy: 0.7278
# Saving ...
# Optimization finished.

# %%
# plot loss

plt.xlabel('Epoches')
plt.ylabel('loss')

plt.plot(epoches,training_losses,"x-",label="training loss")
plt.plot(epoches,validation_losses,"+-",label="validation loss")

plt.grid(True)
plt.legend(bbox_to_anchor=(1.0, 1), loc=1, borderaxespad=0.)

plt.show()

# plot accuracy
plt.xlabel('Epoches')
plt.ylabel('accuracy')

plt.plot(epoches,training_accuracies,"x-",label="training accuracy")
plt.plot(epoches,validation_accuracies,"+-",label="validation accuracy")

plt.grid(True)
plt.legend(bbox_to_anchor=(1.0, 0.2), loc=1, borderaxespad=0.)

plt.show()
